# %%
import gensim
from gensim import corpora, models
import pyLDAvis
import pyLDAvis.gensim
from sklearn.externals import joblib

dictionary = gensim.corpora.Dictionary.load_from_text('lemmas_nostopwords_with_otherdatacleaning_dictionary_result.txt')
corpus = gensim.corpora.MmCorpus('lemmas_nostopwords_corpus_result.mm')
lda = joblib.load('ldamodel_result.pkl')
lda_vis = pyLDAvis.gensim.prepare(lda, corpus, dictionary)
pyLDAvis.display(lda_vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el88011406104581500169253658099"></div>
# <script type="text/javascript">
#
# ...
